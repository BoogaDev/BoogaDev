# %%
import pandas
import pathlib
import os
import shutil

# %%
def get_dataframes(p):
    if 'parquet' in p:
        return pandas.read_parquet(p)
    elif '.csv' in p:
        return pandas.read_csv(p)
    elif '.json' in p:
        return pandas.read_json(p) 
    else:
        raise ValueError

def get_paths(path, make_df=False):
    path = pathlib.Path(path)
    lst = [str(l) for l in list(path.rglob('*')) if '.parquet.gzip' in str(l)]
    if make_df:
        lst = [get_dataframes(p) for p in lst]
    return lst


def common_member(a, b):
    a_set = set(a)
    b_set = set(b)

    if (a_set & b_set):
        print(a_set & b_set)
    else:
        print("No common elements")

def auto_key(df_cluster):
    keys = set()
    for df in df_cluster:
        pointer_keys = set(df.columns)
        if (keys & pointer_keys):
                print(keys & pointer_keys)
        else:
            keys = pointer_keys
       


def join_HDF(df_cluster, key=None):

    master = None
    for df in df_cluster:
        print(master)
        if master:
            master = pandas.concat(df)
        else:
            master = df
        print(master)
        break


def join_VDF():
    # Joing Data Vertically 
    pass


auto_key(get_paths('./data/team/', True))

# join_HDF(get_paths('./data/team/', True))
# Out:
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'opponentTeamAbbrev', 'teamId'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'opponentTeamAbbrev', 'teamId'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'opponentTeamAbbrev', 'teamId'}
# {'homeRoad', 'gamesPlayed', 'teamFullName', 'gameDate', 'gameId', 'teamId', 'opponentTeamAbbrev', 'pointPct'}
# ...

# %%
# src_paths = get_paths('./data/team/')
# dst_paths = [x.replace('/data.parquet.gzip', '_data.parquet.gzip') for x in src_paths]
# for x in range(len(src_paths)): shutil.move(src_paths[x], dst_paths[x])
df_0 = pandas.read_parquet('data/team/summary_data.parquet.gzip')
df_1 = pandas.read_parquet('data/team/daysbetweengames_data.parquet.gzip')
df_2 = pandas.read_parquet('data/team/faceoffpercentages_data.parquet.gzip')
df_3 = pandas.read_parquet('data/team/faceoffwins_data.parquet.gzip')
df_4 = pandas.read_parquet('data/team/goalgames_data.parquet.gzip')
df_5 = pandas.read_parquet('data/team/goalsagainstbystrength_data.parquet.gzip')
df_6 = pandas.read_parquet('data/team/goalsbyperiod_data.parquet.gzip')
df_7 = pandas.read_parquet('data/team/goalsforbystrength_data.parquet.gzip')
df_8 = pandas.read_parquet('data/team/leadingtrailing_data.parquet.gzip')
df_9 = pandas.read_parquet('data/team/outshootoutshotby_data.parquet.gzip')
df_10 = pandas.read_parquet('data/team/penalties_data.parquet.gzip')
df_11 = pandas.read_parquet('data/team/penaltykill_data.parquet.gzip')
df_12 = pandas.read_parquet('data/team/penaltykilltime_data.parquet.gzip')
df_13 = pandas.read_parquet('data/team/percentages_data.parquet.gzip')
df_14 = pandas.read_parquet('data/team/powerplay_data.parquet.gzip')
df_15 = pandas.read_parquet('data/team/powerplaytime_data.parquet.gzip')
df_16 = pandas.read_parquet('data/team/realtime_data.parquet.gzip')
df_17 = pandas.read_parquet('data/team/scoretrailfirst_data.parquet.gzip')
df_18 = pandas.read_parquet('data/team/shootout_data.parquet.gzip')
df_19 = pandas.read_parquet('data/team/shottype_data.parquet.gzip')
df_20 = pandas.read_parquet('data/team/summaryshooting_data.parquet.gzip')

# %%
df_0.gameId = df_0.gameId.astype('str')
df_1.gameId = df_1.gameId.astype('str')
df_2.gameId = df_2.gameId.astype('str')
df_3.gameId = df_3.gameId.astype('str')
df_4.gameId = df_4.gameId.astype('str')
df_5.gameId = df_5.gameId.astype('str')
df_6.gameId = df_6.gameId.astype('str')
df_7.gameId = df_7.gameId.astype('str')
df_8.gameId = df_8.gameId.astype('str')
df_9.gameId = df_9.gameId.astype('str')
df_10.gameId = df_10.gameId.astype('str')
df_11.gameId = df_11.gameId.astype('str')
df_12.gameId = df_12.gameId.astype('str')
df_13.gameId = df_13.gameId.astype('str')
df_14.gameId = df_14.gameId.astype('str')
df_15.gameId = df_15.gameId.astype('str')
df_16.gameId = df_16.gameId.astype('str')
df_17.gameId = df_17.gameId.astype('str')
df_18.gameId = df_18.gameId.astype('str')
df_19.gameId = df_19.gameId.astype('str')
df_20.gameId = df_20.gameId.astype('str')

# %%
df_0.set_index(['gameId', 'teamId'], inplace=True)
df_1.set_index(['gameId', 'teamId'], inplace=True)
df_2.set_index(['gameId', 'teamId'], inplace=True)
df_3.set_index(['gameId', 'teamId'], inplace=True)
df_4.set_index(['gameId', 'teamId'], inplace=True)
df_5.set_index(['gameId', 'teamId'], inplace=True)
df_6.set_index(['gameId', 'teamId'], inplace=True)
df_7.set_index(['gameId', 'teamId'], inplace=True)
df_8.set_index(['gameId', 'teamId'], inplace=True)
df_9.set_index(['gameId', 'teamId'], inplace=True)
df_10.set_index(['gameId', 'teamId'], inplace=True)
df_11.set_index(['gameId', 'teamId'], inplace=True)
df_12.set_index(['gameId', 'teamId'], inplace=True)
df_13.set_index(['gameId', 'teamId'], inplace=True)
df_14.set_index(['gameId', 'teamId'], inplace=True)
df_15.set_index(['gameId', 'teamId'], inplace=True)
df_16.set_index(['gameId', 'teamId'], inplace=True)
df_17.set_index(['gameId', 'teamId'], inplace=True)
df_18.set_index(['gameId', 'teamId'], inplace=True)
df_19.set_index(['gameId', 'teamId'], inplace=True)
df_20.set_index(['gameId', 'teamId'], inplace=True)

# %%
df_0.sort_index(inplace=True)
df_1.sort_index(inplace=True)
df_2.sort_index(inplace=True)
df_3.sort_index(inplace=True)
df_4.sort_index(inplace=True)
df_5.sort_index(inplace=True)
df_6.sort_index(inplace=True)
df_7.sort_index(inplace=True)
df_8.sort_index(inplace=True)
df_9.sort_index(inplace=True)
df_10.sort_index(inplace=True)
df_11.sort_index(inplace=True)
df_12.sort_index(inplace=True)
df_13.sort_index(inplace=True)
df_14.sort_index(inplace=True)
df_15.sort_index(inplace=True)
df_16.sort_index(inplace=True)
df_17.sort_index(inplace=True)
df_18.sort_index(inplace=True)
df_19.sort_index(inplace=True)
df_20.sort_index(inplace=True)

# %%
df_0.drop_duplicates(inplace=True)
df_1.drop_duplicates(inplace=True)
df_2.drop_duplicates(inplace=True)
df_3.drop_duplicates(inplace=True)
df_4.drop_duplicates(inplace=True)
df_5.drop_duplicates(inplace=True)
df_6.drop_duplicates(inplace=True)
df_7.drop_duplicates(inplace=True)
df_8.drop_duplicates(inplace=True)
df_9.drop_duplicates(inplace=True)
df_10.drop_duplicates(inplace=True)
df_11.drop_duplicates(inplace=True)
df_12.drop_duplicates(inplace=True)
df_13.drop_duplicates(inplace=True)
df_14.drop_duplicates(inplace=True)
df_15.drop_duplicates(inplace=True)
df_16.drop_duplicates(inplace=True)
df_17.drop_duplicates(inplace=True)
df_18.drop_duplicates(inplace=True)
df_19.drop_duplicates(inplace=True)
df_20.drop_duplicates(inplace=True)

# %%
def common_member(a, b):
    a_set = set(a)
    b_set = set(b)

    # check length
    if len(a_set.intersection(b_set)) > 0:
        return (a_set.intersection(b_set))
    else:
        return ("no common elements")

# %%
# print(df_1.columns)
# print(df_2.columns)
# print(df_3.columns)
# print(df_4.columns)
# print(df_5.columns)
# print(df_6.columns)
# print(df_7.columns)
# print(df_8.columns)
# print(df_9.columns)
# print(df_10.columns)
# print(df_11.columns)
# print(df_12.columns)
# print(df_13.columns)
# print(df_14.columns)
# print(df_15.columns)
# print(df_16.columns)
# print(df_17.columns)
# print(df_18.columns)
# print(df_19.columns)
# print(df_20.columns)
# col_matrix = [df_0.columns, df_1.columns,
#               df_2.columns, df_3.columns, 
#               df_4.columns, df_5.columns,
#               df_6.columns, df_7.columns, 
#               df_8.columns, df_9.columns,
#               df_10.columns, df_11.columns,
#               df_12.columns, df_13.columns,
#               df_14.columns, df_15.columns, 
#               df_16.columns, df_17.columns,
#               df_18.columns, df_19.columns,
#               df_20.columns]

# for item in col_matrix:
#     for item_ in col_matrix:
#         print(common_member(item, item_))

# %%
info = [df_0.info(),
df_1.info(),
df_2.info(),
df_3.info(),
df_4.info(),
df_5.info(),
df_6.info(),
df_7.info(),
df_8.info(),
df_9.info(),
df_10.info(),
df_11.info(),
df_12.info(),
df_13.info(),
df_14.info(),
df_15.info(),
df_16.info(),
df_17.info(),
df_18.info(),
df_19.info(),
df_20.info()
]
for x in info:
    print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   faceoffWinPct        34280 non-null  float64
#  1   gameDate             34280 non-null  object
#  2   gamesPlayed          34280 non-null  int64
#  3   goalsAgainst         34280 non-null  int64
#  4   goalsAgainstPerGame  34280 non-null  float64
#  5   goalsFor             34280 non-null  int64
#  6   goalsForPerGame      34280 non-null  float64
#  7   homeRoad             34280 non-null  object
#  8   losses               34280 non-null  int64
#  9   opponentTeamAbbrev   34280 non-null  object
#  10  otLosses             34280 non-null  int64
#  11  penaltyKillNetPct    33676 non-null  float64
#  12  penaltyKillPct       33676 non-null  float64
#  13  pointPct             34280 non-null  float64
# ...

# %%
df_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   faceoffWinPct        34280 non-null  float64
#  1   gameDate             34280 non-null  object
#  2   gamesPlayed          34280 non-null  int64
#  3   goalsAgainst         34280 non-null  int64
#  4   goalsAgainstPerGame  34280 non-null  float64
#  5   goalsFor             34280 non-null  int64
#  6   goalsForPerGame      34280 non-null  float64
#  7   homeRoad             34280 non-null  object
#  8   losses               34280 non-null  int64
#  9   opponentTeamAbbrev   34280 non-null  object
#  10  otLosses             34280 non-null  int64
#  11  penaltyKillNetPct    33676 non-null  float64
#  12  penaltyKillPct       33676 non-null  float64
#  13  pointPct             34280 non-null  float64
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 29910 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   daysRest                 29910 non-null  int64
#  1   faceoffWinPct            29910 non-null  float64
#  2   gameDate                 29910 non-null  object
#  3   gamesPlayed              29910 non-null  int64
#  4   goalsAgainstPerGame      29910 non-null  float64
#  5   goalsForPerGame          29910 non-null  float64
#  6   homeRoad                 29910 non-null  object
#  7   losses                   29910 non-null  int64
#  8   netGoalsPerGame          29910 non-null  float64
#  9   opponentTeamAbbrev       29910 non-null  object
#  10  otLosses                 29910 non-null  int64
#  11  penaltyKillPct           29368 non-null  float64
#  12  pointPct                 29910 non-null  float64
# ...

# %%
cols_to_use = df_1.columns.difference(df_0.columns)
base = df_0.join(df_1[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31417 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   defensiveZoneFaceoffPct  28955 non-null  float64
#  1   defensiveZoneFaceoffs    28957 non-null  float64
#  2   evFaceoffPct             31417 non-null  float64
#  3   evFaceoffs               31417 non-null  int64
#  4   faceoffWinPct            31417 non-null  float64
#  5   gameDate                 31417 non-null  object
#  6   gamesPlayed              31417 non-null  int64
#  7   homeRoad                 31417 non-null  object
#  8   neutralZoneFaceoffPct    28955 non-null  float64
#  9   neutralZoneFaceoffs      28957 non-null  float64
#  10  offensiveZoneFaceoffPct  28955 non-null  float64
#  11  offensiveZoneFaceoffs    28957 non-null  float64
#  12  opponentTeamAbbrev       31417 non-null  object
# ...

# %%
cols_to_use = df_2.columns.difference(base.columns)
base = base.join(df_2[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
print(base.shape)
base.neutralZoneFaceoffPct.isnull().sum()
# Out:
# (34280, 43)
# 5325

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30877 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   defensiveZoneFaceoffLosses  28417 non-null  float64
#  1   defensiveZoneFaceoffWins    28417 non-null  float64
#  2   defensiveZoneFaceoffs       28417 non-null  float64
#  3   evFaceoffs                  30877 non-null  int64
#  4   evFaceoffsLost              30877 non-null  int64
#  5   evFaceoffsWon               30877 non-null  int64
#  6   faceoffWinPct               30877 non-null  float64
#  7   faceoffsLost                30877 non-null  int64
#  8   faceoffsWon                 30877 non-null  int64
#  9   gameDate                    30877 non-null  object
#  10  gamesPlayed                 30877 non-null  int64
#  11  homeRoad                    30877 non-null  object
# ...

# %%
cols_to_use = df_3.columns.difference(base.columns)
base = base.join(df_3[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gameDate              34280 non-null  object
#  1   gamesPlayed           34280 non-null  int64
#  2   homeRoad              34280 non-null  object
#  3   losses                34280 non-null  int64
#  4   lossesOneGoalGames    34280 non-null  int64
#  5   lossesThreeGoalGames  34280 non-null  int64
#  6   lossesTwoGoalGames    34280 non-null  int64
#  7   opponentTeamAbbrev    34280 non-null  object
#  8   otLosses              34280 non-null  int64
#  9   otLossesOneGoalGames  34280 non-null  int64
#  10  pointPct              34280 non-null  float64
#  11  points                34280 non-null  int64
#  12  teamFullName          34280 non-null  object
#  13  ties                  34280 non-null  int64
# ...

# %%
cols_to_use = df_4.columns.difference(base.columns)
base = base.join(df_4[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34130 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gameDate                  34130 non-null  object
#  1   gamesPlayed               34130 non-null  int64
#  2   goalsAgainst              34130 non-null  int64
#  3   goalsAgainst3On3          29672 non-null  float64
#  4   goalsAgainst3On4          29672 non-null  float64
#  5   goalsAgainst3On5          29672 non-null  float64
#  6   goalsAgainst3On6          29672 non-null  float64
#  7   goalsAgainst4On3          29672 non-null  float64
#  8   goalsAgainst4On4          29672 non-null  float64
#  9   goalsAgainst4On5          29672 non-null  float64
#  10  goalsAgainst4On6          29672 non-null  float64
#  11  goalsAgainst5On3          29672 non-null  float64
#  12  goalsAgainst5On4          29672 non-null  float64
# ...

# %%
cols_to_use = df_5.columns.difference(base.columns)
base = base.join(df_5[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
print(base.shape)
base.goalsAgainst5On4.isnull().sum()
# Out:
# (34280, 83)
# 4608

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31068 entries, ('2008020001.0', 3) to ('nan', 52)
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evGoalsFor            31068 non-null  int64
#  1   gameDate              31068 non-null  object
#  2   gamesPlayed           31068 non-null  int64
#  3   goalsAgainst          31068 non-null  int64
#  4   goalsFor              31068 non-null  int64
#  5   homeRoad              31068 non-null  object
#  6   losses                31068 non-null  int64
#  7   opponentTeamAbbrev    31068 non-null  object
#  8   otLosses              31068 non-null  int64
#  9   period1GoalsAgainst   30868 non-null  float64
#  10  period1GoalsFor       30865 non-null  float64
#  11  period2GoalsAgainst   30851 non-null  float64
#  12  period2GoalsFor       30855 non-null  float64
#  13  period3GoalsAgainst   30797 non-null  float64
# ...

# %%
cols_to_use = df_6.columns.difference(base.columns)
base = base.join(df_6[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34162 entries, ('2009020001.0', 6) to ('nan', 55)
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gameDate              34162 non-null  object
#  1   gamesPlayed           34162 non-null  int64
#  2   goalsAgainst          34162 non-null  int64
#  3   goalsFor              34162 non-null  int64
#  4   goalsFor3On3          29701 non-null  float64
#  5   goalsFor3On4          29701 non-null  float64
#  6   goalsFor3On5          29701 non-null  float64
#  7   goalsFor3On6          29701 non-null  float64
#  8   goalsFor4On3          29701 non-null  float64
#  9   goalsFor4On4          29701 non-null  float64
#  10  goalsFor4On5          29701 non-null  float64
#  11  goalsFor4On6          29701 non-null  float64
#  12  goalsFor5On3          29701 non-null  float64
#  13  goalsFor5On4          29701 non-null  float64
# ...

# %%
cols_to_use = df_7.columns.difference(base.columns)
base = base.join(df_7[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30048 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gameDate             30048 non-null  object
#  1   gamesPlayed          30048 non-null  int64
#  2   homeRoad             30048 non-null  object
#  3   lossLeadPeriod1      30048 non-null  int64
#  4   lossLeadPeriod2      30048 non-null  int64
#  5   lossTrailPeriod1     30048 non-null  int64
#  6   lossTrailPeriod2     30048 non-null  int64
#  7   opponentTeamAbbrev   30048 non-null  object
#  8   otLossLeadPeriod1    30048 non-null  int64
#  9   otLossLeadPeriod2    30048 non-null  int64
#  10  otLossTrailPeriod1   30048 non-null  int64
#  11  otLossTrailPeriod2   30048 non-null  int64
#  12  period1GoalsAgainst  30048 non-null  int64
#  13  period1GoalsFor      30048 non-null  int64
#  14  period2GoalsAgainst  30048 non-null  int64
# ...

# %%
cols_to_use = df_8.columns.difference(base.columns)
base = base.join(df_8[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gameDate                   34280 non-null  object
#  1   gamesPlayed                34280 non-null  int64
#  2   homeRoad                   34280 non-null  object
#  3   losses                     34280 non-null  int64
#  4   lossesEvenShots            34280 non-null  int64
#  5   lossesOutshootOpponent     34280 non-null  int64
#  6   lossesOutshotByOpponent    34280 non-null  int64
#  7   netShotsPerGame            34280 non-null  float64
#  8   opponentTeamAbbrev         34280 non-null  object
#  9   otLosses                   34280 non-null  int64
#  10  otLossesEvenShots          34280 non-null  int64
#  11  otLossesOutshootOpponent   34280 non-null  int64
#  12  otLossesOutshotByOpponent  34280 non-null  int64
# ...

# %%
cols_to_use = df_9.columns.difference(base.columns)
base = base.join(df_9[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 33884 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   benchMinorPenalties    33884 non-null  int64
#  1   gameDate               33884 non-null  object
#  2   gameMisconducts        33884 non-null  int64
#  3   gamesPlayed            33884 non-null  int64
#  4   homeRoad               33884 non-null  object
#  5   losses                 33884 non-null  int64
#  6   majors                 33884 non-null  int64
#  7   matchPenalties         33884 non-null  int64
#  8   minors                 33884 non-null  int64
#  9   misconducts            33884 non-null  int64
#  10  netPenalties           33884 non-null  int64
#  11  netPenaltiesPer60      33884 non-null  float64
#  12  opponentTeamAbbrev     33884 non-null  object
#  13  otLosses               33884 non-null  int64
# ...

# %%
cols_to_use = df_10.columns.difference(base.columns)
base = base.join(df_10[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameDate                 34280 non-null  object
#  1   gamesPlayed              34280 non-null  int64
#  2   homeRoad                 34280 non-null  object
#  3   losses                   34280 non-null  int64
#  4   opponentTeamAbbrev       34280 non-null  object
#  5   otLosses                 34280 non-null  int64
#  6   penaltyKillNetPct        33676 non-null  float64
#  7   penaltyKillPct           33676 non-null  float64
#  8   pkNetGoals               34280 non-null  int64
#  9   pkNetGoalsPerGame        34280 non-null  float64
#  10  pkTimeOnIcePerGame       34280 non-null  float64
#  11  points                   34280 non-null  int64
#  12  pointsPct                34280 non-null  float64
# ...

# %%
cols_to_use = df_11.columns.difference(base.columns)
base = base.join(df_11[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 33854 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameDate                 33854 non-null  object
#  1   gamesPlayed              33854 non-null  int64
#  2   goalsAgainst3v4          31394 non-null  float64
#  3   goalsAgainst3v5          31394 non-null  float64
#  4   goalsAgainst4v5          31394 non-null  float64
#  5   homeRoad                 33854 non-null  object
#  6   opponentTeamAbbrev       33854 non-null  object
#  7   overallPenaltyKillPct    30808 non-null  float64
#  8   penaltyKillPct3v4        2135 non-null   float64
#  9   penaltyKillPct3v5        3652 non-null   float64
#  10  penaltyKillPct4v5        30760 non-null  float64
#  11  pointPct                 33854 non-null  float64
#  12  shorthandedGoalsAgainst  31394 non-null  float64
# ...

# %%
cols_to_use = df_12.columns.difference(base.columns)
base = base.join(df_12[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30531 entries, ('2009020001', 15) to ('2022020990', 4)
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameDate                30531 non-null  object
#  1   gamesPlayed             30531 non-null  int64
#  2   goalsForPct             29560 non-null  float64
#  3   homeRoad                30531 non-null  object
#  4   opponentTeamAbbrev      30531 non-null  object
#  5   pointPct                30531 non-null  float64
#  6   points                  30531 non-null  int64
#  7   satPct                  30527 non-null  float64
#  8   satPctAhead             20106 non-null  float64
#  9   satPctBehind            20088 non-null  float64
#  10  satPctClose             30526 non-null  float64
#  11  satPctTied              30034 non-null  float64
#  12  savePct5v5              30376 non-null  float64
# ...

# %%
cols_to_use = df_13.columns.difference(base.columns)
base = base.join(df_13[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameDate                34280 non-null  object
#  1   gamesPlayed             34280 non-null  int64
#  2   homeRoad                34280 non-null  object
#  3   losses                  34280 non-null  int64
#  4   opponentTeamAbbrev      34280 non-null  object
#  5   otLosses                34280 non-null  int64
#  6   pointPct                34280 non-null  float64
#  7   points                  34280 non-null  int64
#  8   powerPlayGoalsFor       34280 non-null  int64
#  9   powerPlayNetPct         33676 non-null  float64
#  10  powerPlayPct            33676 non-null  float64
#  11  ppGoalsPerGame          34280 non-null  float64
#  12  ppNetGoals              34280 non-null  int64
# ...

# %%
cols_to_use = df_14.columns.difference(base.columns)
base = base.join(df_14[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31609 entries, ('2009020001', 6) to ('2022020990', 7)
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gameDate             31609 non-null  object
#  1   gamesPlayed          31609 non-null  int64
#  2   goals4v3             31609 non-null  int64
#  3   goals5v3             31609 non-null  int64
#  4   goals5v4             31609 non-null  int64
#  5   homeRoad             31609 non-null  object
#  6   opponentTeamAbbrev   31609 non-null  object
#  7   opportunities4v3     31609 non-null  int64
#  8   opportunities5v3     31609 non-null  int64
#  9   opportunities5v4     31609 non-null  int64
#  10  overallPowerPlayPct  31019 non-null  float64
#  11  pointPct             31609 non-null  float64
#  12  powerPlayGoalsFor    31609 non-null  int64
#  13  powerPlayPct4v3      2160 non-null   float64
# ...

# %%
cols_to_use = df_15.columns.difference(base.columns)
base = base.join(df_15[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
print(base.shape)
base.timeOnIce5v4.isnull().sum()
# Out:
# (34280, 217)
# 2671

# %%
df_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31828 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   blockedShots         31828 non-null  int64
#  1   blockedShotsPer60    31828 non-null  float64
#  2   emptyNetGoals        31828 non-null  int64
#  3   gameDate             31828 non-null  object
#  4   gamesPlayed          31828 non-null  int64
#  5   giveaways            31828 non-null  int64
#  6   giveawaysPer60       31828 non-null  float64
#  7   hits                 31828 non-null  int64
#  8   hitsPer60            31828 non-null  float64
#  9   homeRoad             31828 non-null  object
#  10  missedShots          31828 non-null  int64
#  11  opponentTeamAbbrev   31828 non-null  object
#  12  satPct               29384 non-null  float64
#  13  takeaways            31828 non-null  int64
# ...

# %%
cols_to_use = df_16.columns.difference(base.columns)
base = base.join(df_16[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34260 entries, ('2008020001', 3) to ('2022020990', 7)
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gameDate                  34260 non-null  object
#  1   gamesPlayed               34260 non-null  int64
#  2   homeRoad                  34260 non-null  object
#  3   losses                    34260 non-null  int64
#  4   lossesScoringFirst        34260 non-null  int64
#  5   lossesTrailingFirst       34260 non-null  int64
#  6   opponentTeamAbbrev        34260 non-null  object
#  7   otLosses                  34260 non-null  int64
#  8   otLossesScoringFirst      34260 non-null  int64
#  9   otLossesTrailingFirst     34260 non-null  int64
#  10  points                    34260 non-null  int64
#  11  scoringFirstGamesPlayed   34260 non-null  int64
#  12  teamFullName              34260 non-null  object
# ...

# %%
cols_to_use = df_17.columns.difference(base.columns)
base = base.join(df_17[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 29975 entries, ('2008020001', 3) to ('2022020990', 4)
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gameDate                     29975 non-null  object
#  1   gamesPlayed                  29975 non-null  int64
#  2   homeRoad                     29975 non-null  object
#  3   losses                       29975 non-null  int64
#  4   opponentTeamAbbrev           29975 non-null  object
#  5   otLosses                     29975 non-null  int64
#  6   pointPct                     29975 non-null  float64
#  7   points                       29975 non-null  int64
#  8   shootoutGamesPlayed          29975 non-null  int64
#  9   shootoutGoals                29975 non-null  int64
#  10  shootoutGoalsAgainst         29975 non-null  int64
#  11  shootoutLosses               29975 non-null  int64
# ...

# %%
cols_to_use = df_18.columns.difference(base.columns)
base = base.join(df_18[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
import numpy as np
df_19.info()
df_19.head()
# df_19.loc[df_19["shotsOnNetSlap"] == "NaN", "shotsOnNetSlap"] = np.nan
df_19[df_19["shotsOnNetSlap"].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001.0', 3) to ('nan', 14)
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gameDate               34280 non-null  object
#  1   gamesPlayed            34280 non-null  int64
#  2   goalsBackhand          31818 non-null  float64
#  3   goalsDeflected         31818 non-null  float64
#  4   goalsFor               34280 non-null  int64
#  5   goalsSlap              31818 non-null  float64
#  6   goalsSnap              31818 non-null  float64
#  7   goalsTipIn             31818 non-null  float64
#  8   goalsWrapAround        31818 non-null  float64
#  9   goalsWrist             31818 non-null  float64
#  10  homeRoad               34280 non-null  object
#  11  opponentTeamAbbrev     34280 non-null  object
#  12  shootingPct            34280 non-null  float64
#  13  shootingPctBackhand    28845 non-null  float64
# ...

# %%
cols_to_use = df_19.columns.difference(base.columns)
base = base.join(df_19[cols_to_use])
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
print(base.shape)
base.shotsOnNetWrapAround.isnull().sum()
# Out:
# (34280, 276)
# 34280

# %%
df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 33811 entries, ('2009020001.0', 6.0) to ('nan', nan)
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gameDate            33811 non-null  object
#  1   gamesPlayed         33811 non-null  int64
#  2   homeRoad            33811 non-null  object
#  3   opponentTeamAbbrev  33811 non-null  object
#  4   satAgainst          31349 non-null  float64
#  5   satAhead            30895 non-null  float64
#  6   satBehind           30923 non-null  float64
#  7   satClose            31348 non-null  float64
#  8   satFor              31349 non-null  float64
#  9   satTied             31253 non-null  float64
#  10  satTotal            31349 non-null  float64
#  11  shots5v5            31349 non-null  float64
#  12  teamFullName        33811 non-null  object
#  13  usatAgainst         31349 non-null  float64
#  14  usatAhead           30880 non-null  float64
# ...

# %%
cols_to_use = df_20.columns.difference(base.columns)
base = base.join(df_20[cols_to_use])
base.head(10)

# %%
base.to_parquet('data/joined_team_data.parquet.gzip')
base = pandas.read_parquet('data/joined_team_data.parquet.gzip')
base.info()
