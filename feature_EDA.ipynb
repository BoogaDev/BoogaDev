# %%
import pandas
base = pandas.read_parquet('data/joined_team_data.parquet.gzip')
base.head(10)
# Out:
#                    faceoffWinPct    gameDate  gamesPlayed  goalsAgainst  \
# gameId     teamId
# 2008020001 3            0.483870  2008-10-04            1             1
#            14           0.516129  2008-10-04            1             2
# 2008020002 5            0.466666  2008-10-04            1             3
#            9            0.533333  2008-10-04            1             4
# 2008020003 3            0.369565  2008-10-05            1             1
#            14           0.630434  2008-10-05            1             2
# 2008020004 5            0.508771  2008-10-05            1             3
#            9            0.491228  2008-10-05            1             1
# 2008020005 10           0.355932  2008-10-09            1             2
#            17           0.644067  2008-10-09            1             3
#
#                    goalsAgainstPerGame  goalsFor  goalsForPerGame homeRoad  \
# gameId     teamId
# ...

# %%
base.goalsSlap
# Out:
# gameId      teamId
# 2008020001  3        NaN
#             14       NaN
# 2008020002  5        NaN
#             9        NaN
# 2008020003  3        NaN
#                       ..
# 2022020778  30       NaN
# 2022020779  19       NaN
#             53       NaN
# 2022020990  4        NaN
#             7        NaN
# Name: goalsSlap, Length: 34280, dtype: float64

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 34280 entries, ('2008020001', 3) to ('2022020990', 7)
# Columns: 291 entries, faceoffWinPct to usatTotal
# dtypes: float64(250), int64(36), object(5)
# memory usage: 76.8+ MB

# %%
lis = base.isnull().sum()[base.isnull().sum() == 34280].index
lis
# Out:
# Index(['ties', 'evGoalsFor', 'period1GoalsAgainst', 'period1GoalsFor',
#        'period2GoalsAgainst', 'period2GoalsFor', 'period3GoalsAgainst',
#        'period3GoalsFor', 'periodOtGoalsAgainst', 'periodOtGoalsFor',
#        'ppGoalsFor', 'shGoalsFor', 'goalsFor3On3', 'goalsFor3On4',
#        'goalsFor3On5', 'goalsFor3On6', 'goalsFor4On3', 'goalsFor4On4',
#        'goalsFor4On5', 'goalsFor4On6', 'goalsFor5On3', 'goalsFor5On4',
#        'goalsFor5On5', 'goalsFor5On6', 'goalsFor6On3', 'goalsFor6On4',
#        'goalsFor6On5', 'goalsForPenaltyShots', 'goalsBackhand',
#        'goalsDeflected', 'goalsSlap', 'goalsSnap', 'goalsTipIn',
#        'goalsWrapAround', 'goalsWrist', 'shootingPct', 'shootingPctBackhand',
#        'shootingPctDeflected', 'shootingPctSlap', 'shootingPctSnap',
#        'shootingPctTipIn', 'shootingPctWrapAround', 'shootingPctWrist',
#        'shotsOnNet', 'shotsOnNetBackhand', 'shotsOnNetDeflected',
#        'shotsOnNetSlap', 'shotsOnNetSnap', 'shotsOnNetTipIn',
# ...

# %%
base.describe().T
# Out:
#                        count      mean       std       min      25%  50%  \
# faceoffWinPct        34280.0  0.499998  0.072836  0.170212  0.45098  0.5
# gamesPlayed          34280.0  1.000000  0.000000  1.000000  1.00000  1.0
# goalsAgainst         34280.0  2.823600  1.666412  0.000000  2.00000  3.0
# goalsAgainstPerGame  34280.0  2.823600  1.666412  0.000000  2.00000  3.0
# goalsFor             34280.0  2.823600  1.666412  0.000000  2.00000  3.0
# ...                      ...       ...       ...       ...      ...  ...
# usatBehind               0.0       NaN       NaN       NaN      NaN  NaN
# usatClose                0.0       NaN       NaN       NaN      NaN  NaN
# usatFor                  0.0       NaN       NaN       NaN      NaN  NaN
# usatTied                 0.0       NaN       NaN       NaN      NaN  NaN
# usatTotal                0.0       NaN       NaN       NaN      NaN  NaN
#
#                           75%        max
# faceoffWinPct        0.549019   0.829787
# ...
